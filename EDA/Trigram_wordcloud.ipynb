# %% [markdown]
# ## Coded By Frank Zhao

# %% [markdown]
# #### To solve autofill not functioning in Jupyter Lab, use the code below

# %%
# %config Completer.use_jedi = False

# %%
import pandas as pd
import numpy as np 
from os import path
from PIL import Image
from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator
from nltk.corpus import stopwords
from tensorflow.keras.preprocessing.text import Tokenizer
import matplotlib.pyplot as plt
import re
import nltk
import pickle
from sklearn.feature_extraction.text import CountVectorizer
# %matplotlib inline

# %% [markdown]
# ### Import data

# %%
imdb = pd.read_csv(".\data\IMDB.csv")

# %%
imdb.head(10)
# Out:
#                                               review sentiment
# 0  One of the other reviewers has mentioned that ...  positive
# 1  A wonderful little production. <br /><br />The...  positive
# 2  I thought this was a wonderful way to spend ti...  positive
# 3  Basically there's a family where a little boy ...  negative
# 4  Petter Mattei's "Love in the Time of Money" is...  positive
# 5  Probably my all-time favorite movie, a story o...  positive
# 6  I sure would like to see a resurrection of a u...  positive
# 7  This show was an amazing, fresh & innovative i...  negative
# 8  Encouraged by the positive comments about this...  negative
# 9  If you like original gut wrenching laughter yo...  positive

# %%
## check for data balance
imdb['sentiment'].value_counts()
# Out:
# negative    25000
# positive    25000
# Name: sentiment, dtype: int64

# %% [raw]
# This is a balanced dataset

# %% [markdown]
# ### Data Pre-processing

# %%
pwd
# Out:
# 'H:\\Projects\\Drexel\\Capstone II'

# %% [markdown]
# ### lowercase

# %%
imdb['review'] = imdb['review'].str.lower()

# %%
imdb['review'][0]
# Out:
# "one of the other reviewers has mentioned that after watching just 1 oz episode you'll be hooked. they are right, as this is exactly what happened with me.<br /><br />the first thing that struck me about oz was its brutality and unflinching scenes of violence, which set in right from the word go. trust me, this is not a show for the faint hearted or timid. this show pulls no punches with regards to drugs, sex or violence. its is hardcore, in the classic use of the word.<br /><br />it is called oz as that is the nickname given to the oswald maximum security state penitentary. it focuses mainly on emerald city, an experimental section of the prison where all the cells have glass fronts and face inwards, so privacy is not high on the agenda. em city is home to many..aryans, muslims, gangstas, latinos, christians, italians, irish and more....so scuffles, death stares, dodgy dealings and shady agreements are never far away.<br /><br />i would say the main appeal of the show is due to the fact that it goes where other shows wouldn't dare. forget pretty pictures painted for mainstream audiences, forget charm, forget romance...oz doesn't mess around. the first episode i ever saw struck me as so nasty it was surreal, i couldn't say i was ready for it, but as i watched more, i developed a taste for oz, and got accustomed to the high levels of graphic violence. not just violence, but injustice (crooked guards who'll be sold out for a nickel, inmates who'll kill on order and get away with it, well mannered, middle class inmates being turned into prison bitches due to their lack of street skills or prison experience) watching oz, you may become comfortable with what is uncomfortable viewing....thats if you can get in touch with your darker side."

# %%
## import stopwords
with open(".\data\Exports\master_sw.data", "rb") as file:
    stopwords = pickle.load(file)

# %%
## copy dataframe
df = imdb.copy()

# %% [markdown]
# ### remove <br\>

# %%
df['review']= df['review'].str.replace('<.*?>', "")
# Out:
# <ipython-input-90-8b1516f6d381>:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['review']= df['review'].str.replace('<.*?>', "")

# %% [markdown]
# ### remove `'` ,puncuation and symbols

# %%
df['review'] = df['review'].str.replace("'", " ")

df['review'] = df['review'].str.replace("[^\w\s]"," ")
# Out:
# <ipython-input-91-840fa8b1a4df>:3: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['review'] = df['review'].str.replace("[^\w\s]"," ")

# %%
# %%time
## remove stopwords
df['review_token'] = df['review'].apply(lambda x: [word for word in x.split() if word not in stopwords])
# Out:
# Wall time: 56.4 s

# %%
print(df['review_token'][0])
# Out:
# ['reviewers', 'mentioned', 'watching', '1', 'oz', 'episode', 'hooked', 'right', 'exactly', 'happened', 'thing', 'struck', 'oz', 'brutality', 'unflinching', 'scenes', 'violence', 'set', 'right', 'word', 'trust', 'faint', 'hearted', 'timid', 'pulls', 'punches', 'regards', 'drugs', 'sex', 'violence', 'hardcore', 'classic', 'use', 'word', 'called', 'oz', 'nickname', 'given', 'oswald', 'maximum', 'security', 'state', 'penitentary', 'focuses', 'mainly', 'emerald', 'city', 'experimental', 'section', 'prison', 'cells', 'glass', 'fronts', 'face', 'inwards', 'privacy', 'high', 'agenda', 'em', 'city', 'home', 'aryans', 'muslims', 'gangstas', 'latinos', 'christians', 'italians', 'irish', 'scuffles', 'death', 'stares', 'dodgy', 'dealings', 'shady', 'agreements', 'far', 'away', 'main', 'appeal', 'fact', 'goes', 'shows', 'dare', 'forget', 'pretty', 'pictures', 'painted', 'mainstream', 'audiences', 'forget', 'charm', 'forget', 'romance', 'oz', 'mess', 'episode', 'saw', 'struck', 'nasty', 'surreal', 'ready', 'watched', 'developed', 'taste', 'oz', 'got', 'accustomed', 'high', 'levels', 'graphic', 'violence', 'violence', 'injustice', 'crooked', 'guards', 'sold', 'nickel', 'inmates', 'kill', 'order', 'away', 'mannered', 'middle', 'class', 'inmates', 'turned', 'prison', 'bitches', 'lack', 'street', 'skills', 'prison', 'experience', 'watching', 'oz', 'comfortable', 'uncomfortable', 'viewing', 'thats', 'touch', 'darker']

# %% [markdown]
# ### Lemmatization

# %%
WNlemma = nltk.WordNetLemmatizer()

# %%
# %%time
df['lemma_review'] = df['review_token'].apply(lambda x: [WNlemma.lemmatize(word) for word in x])
# Out:
# Wall time: 13.6 s

# %%
print(df['lemma_review'][0])
# Out:
# ['reviewer', 'mentioned', 'watching', '1', 'oz', 'episode', 'hooked', 'right', 'exactly', 'happened', 'thing', 'struck', 'oz', 'brutality', 'unflinching', 'scene', 'violence', 'set', 'right', 'word', 'trust', 'faint', 'hearted', 'timid', 'pull', 'punch', 'regard', 'drug', 'sex', 'violence', 'hardcore', 'classic', 'use', 'word', 'called', 'oz', 'nickname', 'given', 'oswald', 'maximum', 'security', 'state', 'penitentary', 'focus', 'mainly', 'emerald', 'city', 'experimental', 'section', 'prison', 'cell', 'glass', 'front', 'face', 'inwards', 'privacy', 'high', 'agenda', 'em', 'city', 'home', 'aryan', 'muslim', 'gangsta', 'latino', 'christian', 'italian', 'irish', 'scuffle', 'death', 'stare', 'dodgy', 'dealing', 'shady', 'agreement', 'far', 'away', 'main', 'appeal', 'fact', 'go', 'show', 'dare', 'forget', 'pretty', 'picture', 'painted', 'mainstream', 'audience', 'forget', 'charm', 'forget', 'romance', 'oz', 'mess', 'episode', 'saw', 'struck', 'nasty', 'surreal', 'ready', 'watched', 'developed', 'taste', 'oz', 'got', 'accustomed', 'high', 'level', 'graphic', 'violence', 'violence', 'injustice', 'crooked', 'guard', 'sold', 'nickel', 'inmate', 'kill', 'order', 'away', 'mannered', 'middle', 'class', 'inmate', 'turned', 'prison', 'bitch', 'lack', 'street', 'skill', 'prison', 'experience', 'watching', 'oz', 'comfortable', 'uncomfortable', 'viewing', 'thats', 'touch', 'darker']

# %% [markdown]
# ### Trigrams

# %%
# %%time
df['trigram'] = df['lemma_review'].apply(lambda x: ["_".join(tup) for tup in list(nltk.ngrams(x, 3))])
# Out:
# Wall time: 1.69 s

# %% [markdown]
# * Positive

# %%
df_pos = df[df['sentiment'] == 'positive']

# %%
df_pos_list = df_pos['trigram'].tolist()

# %%
all_pos_trigram = []
for l in df_pos_list:
    all_pos_trigram += l

# %%
# %%time
#Using count vectoriser to view the frequency of bigrams
vectorizer = CountVectorizer(ngram_range=(1, 1))
bag_of_words = vectorizer.fit_transform(all_pos_trigram)
vectorizer.vocabulary_
sum_words = bag_of_words.sum(axis=0) 
pos_words_freq = [(word, sum_words[0, idx]) for word, idx in vectorizer.vocabulary_.items()]
pos_words_freq =sorted(pos_words_freq, key = lambda x: x[1], reverse=True)
print (pos_words_freq[:100])
# Out:
# [('new_york_city', 195), ('world_war_ii', 167), ('based_true_story', 144), ('best_movie_seen', 115), ('seen_long_time', 91), ('highly_recommend_movie', 86), ('international_film_festival', 84), ('feel_good_movie', 79), ('rock_n_roll', 78), ('william_h_macy', 70), ('highly_recommend_film', 70), ('second_world_war', 68), ('low_budget_film', 66), ('sci_fi_movie', 65), ('best_film_seen', 64), ('tour_de_force', 62), ('george_c_scott', 61), ('story_take_place', 60), ('movie_worth_watching', 60), ('12_year_old', 60), ('vote_title_brazil', 60), ('kung_fu_movie', 58), ('year_old_boy', 58), ('10_year_old', 57), ('40_year_old', 56), ('sci_fi_film', 55), ('movie_10_10', 55), ('breath_fresh_air', 53), ('definitely_worth_seeing', 51), ('film_worth_watching', 50), ('year_old_girl', 49), ('film_take_place', 49), ('14_year_old', 49), ('samuel_l_jackson', 48), ('movie_pretty_good', 47), ('good_old_fashioned', 47), ('low_budget_horror', 46), ('martial_art_movie', 46), ('7_5_10', 46), ('pretty_good_movie', 45), ('give_best_performance', 45), ('film_worth_seeing', 44), ('15_year_old', 44), ('low_budget_movie', 44), ('funniest_movie_seen', 43), ('philip_seymour_hoffman', 43), ('texas_chainsaw_massacre', 43), ('robert_de_niro', 43), ('daniel_day_lewis', 42), ('movie_take_place', 42), ('year_old_daughter', 42), ('2001_space_odyssey', 42), ('8_5_10', 41), ('dream_come_true', 41), ('best_supporting_actor', 41), ('film_seen_year', 41), ('time_favorite_movie', 40), ('martial_art_film', 40), ('year_old_virgin', 40), ('definitely_worth_watching', 40), ('dead_end_kid', 40), ('film_tell_story', 39), ('max_von_sydow', 39), ('movie_7_10', 38), ('favorite_movie_time', 38), ('kramer_v_kramer', 38), ('seen_movie_time', 38), ('cuba_gooding_jr', 38), ('robert_downey_jr', 38), ('saving_private_ryan', 37), ('black_white_film', 37), ('edward_g_robinson', 36), ('film_10_10', 36), ('best_year_life', 36), ('8_year_old', 36), ('rating_8_10', 36), ('long_time_ago', 36), ('year_old_son', 36), ('movie_long_time', 36), ('20_year_later', 36), ('science_fiction_film', 36), ('movie_seen_long', 36), ('11_year_old', 36), ('worth_price_admission', 35), ('movie_8_10', 35), ('give_great_performance', 35), ('movie_good_movie', 35), ('look_forward_seeing', 34), ('nightmare_elm_street', 34), ('laugh_loud_funny', 33), ('sci_fi_channel', 33), ('high_school_student', 33), ('movie_definitely_worth', 33), ('movie_worth_seeing', 33), ('academy_award_best', 32), ('supporting_cast_includes', 32), ('thought_provoking_film', 32), ('best_supporting_actress', 32), ('night_living_dead', 31), ('film_year_ago', 31)]
# Wall time: 18.7 s

# %%
WC_height = 750
WC_width = 1500
WC_max_words = 100
max_font_size=325
colormap='Accent'

# %%
# %%time
pos_words_dict = dict(pos_words_freq)
wordCloud = WordCloud(max_words=WC_max_words, height=WC_height, width=WC_width,stopwords=stopwords, colormap=colormap)
wordCloud.generate_from_frequencies(pos_words_dict)

plt.figure(figsize=(20,10), facecolor='k')
plt.imshow(wordCloud, interpolation='bilinear')
plt.axis("off")
plt.show()
wordCloud.to_file('wordcloud_pos_trigram.jpg')
# Out:
# Wall time: 3.16 s

# %% [markdown]
# * Negative

# %%
df_neg = df[df['sentiment'] == 'negative']

# %%
df_neg_list = df_neg['trigram'].tolist()

# %%
all_neg_trigram = []
for l in df_neg_list:
    all_neg_trigram += l

# %%
# %%time
#Using count vectoriser to view the frequency of trigrams
vectorizer = CountVectorizer(ngram_range=(1, 1))
bag_of_words = vectorizer.fit_transform(all_neg_trigram)
vectorizer.vocabulary_
sum_words = bag_of_words.sum(axis=0) 
neg_words_freq = [(word, sum_words[0, idx]) for word, idx in vectorizer.vocabulary_.items()]
neg_words_freq =sorted(neg_words_freq, key = lambda x: x[1], reverse=True)
print (neg_words_freq[:100])
# Out:
# [('worst_movie_seen', 546), ('worst_film_seen', 252), ('waste_time_money', 188), ('sci_fi_channel', 137), ('bad_acting_bad', 136), ('complete_waste_time', 123), ('low_budget_film', 117), ('good_thing_movie', 114), ('low_budget_movie', 114), ('movie_waste_time', 97), ('10_year_old', 94), ('mystery_science_theater', 92), ('low_budget_horror', 90), ('blah_blah_blah', 83), ('new_york_city', 82), ('sci_fi_movie', 82), ('seen_long_time', 81), ('bad_bad_bad', 75), ('waste_time_watching', 72), ('science_theater_3000', 71), ('plan_9_outer', 71), ('9_outer_space', 71), ('12_year_old', 69), ('total_waste_time', 68), ('movie_worth_watching', 64), ('worst_movie_time', 64), ('world_war_ii', 64), ('year_old_boy', 62), ('blair_witch_project', 62), ('sci_fi_film', 62), ('fast_forward_button', 60), ('high_school_student', 59), ('5_year_old', 59), ('good_thing_film', 58), ('14_year_old', 58), ('watching_paint_dry', 57), ('year_old_girl', 57), ('local_video_store', 57), ('movie_seen_life', 56), ('13_year_old', 55), ('movie_bad_movie', 54), ('90_minute_life', 53), ('2_hour_life', 52), ('best_thing_movie', 52), ('looking_forward_seeing', 50), ('movie_worst_movie', 50), ('vote_title_brazil', 49), ('special_effect_bad', 49), ('texas_chainsaw_massacre', 48), ('movie_low_budget', 47), ('based_true_story', 46), ('movie_bad_good', 46), ('waste_time_movie', 46), ('long_time_ago', 46), ('let_start_saying', 46), ('bad_special_effect', 46), ('saturday_night_live', 46), ('movie_take_place', 45), ('nightmare_elm_street', 45), ('rating_4_10', 45), ('waste_money_time', 44), ('stay_away_movie', 44), ('die_hard_fan', 44), ('actually_pretty_good', 44), ('ha_ha_ha', 44), ('soft_core_porn', 44), ('jean_claude_van', 44), ('hand_held_camera', 43), ('movie_read_book', 43), ('casper_van_dien', 43), ('hour_half_life', 43), ('good_horror_movie', 43), ('bad_movie_bad', 42), ('film_waste_time', 42), ('catherine_zeta_jones', 42), ('film_take_place', 42), ('movie_1_10', 41), ('tommy_lee_jones', 41), ('seen_bad_movie', 41), ('manos_hand_fate', 41), ('high_school_play', 41), ('cutting_room_floor', 41), ('claude_van_damme', 41), ('15_year_old', 40), ('movie_seen_long', 40), ('minute_running_time', 39), ('possibly_worst_movie', 39), ('bad_bad_movie', 38), ('far_worst_movie', 38), ('rock_n_roll', 37), ('8_year_old', 37), ('use_term_loosely', 37), ('bad_taste_mouth', 36), ('film_worth_watching', 36), ('avoid_movie_cost', 36), ('gu_van_sant', 36), ('sci_fi_horror', 36), ('horror_movie_seen', 36), ('movie_bad_bad', 36), ('make_little_sense', 36)]
# Wall time: 15.7 s

# %%
# %%time
neg_words_dict = dict(neg_words_freq)
wordCloud = WordCloud(max_words=WC_max_words, height=WC_height, width=WC_width,stopwords=stopwords, colormap=colormap)
wordCloud.generate_from_frequencies(neg_words_dict)
plt.figure(figsize=(20,10), facecolor='k')
plt.imshow(wordCloud, interpolation='bilinear')
plt.axis("off")
plt.show()
wordCloud.to_file('wordcloud_neg_trigram.jpg')
# Out:
# Wall time: 3.03 s

# %% [markdown]
# * Entire

# %%
all_trigram = []
df_all_list = df['trigram'].tolist()
for l in df_all_list:
    all_trigram += l

# %%
# %%time
#Using count vectoriser to view the frequency of bigrams
vectorizer = CountVectorizer(ngram_range=(1, 1))
bag_of_words = vectorizer.fit_transform(all_trigram)
vectorizer.vocabulary_
sum_words = bag_of_words.sum(axis=0) 
all_words_freq = [(word, sum_words[0, idx]) for word, idx in vectorizer.vocabulary_.items()]
all_words_freq =sorted(all_words_freq, key = lambda x: x[1], reverse=True)
print (all_words_freq[:100])
# Out:
# [('worst_movie_seen', 552), ('new_york_city', 277), ('worst_film_seen', 254), ('world_war_ii', 231), ('based_true_story', 190), ('waste_time_money', 190), ('low_budget_film', 183), ('seen_long_time', 172), ('sci_fi_channel', 170), ('low_budget_movie', 158), ('10_year_old', 151), ('sci_fi_movie', 147), ('bad_acting_bad', 143), ('good_thing_movie', 138), ('low_budget_horror', 136), ('12_year_old', 129), ('best_movie_seen', 127), ('complete_waste_time', 126), ('movie_worth_watching', 124), ('year_old_boy', 120), ('sci_fi_film', 117), ('rock_n_roll', 115), ('vote_title_brazil', 109), ('14_year_old', 107), ('year_old_girl', 106), ('international_film_festival', 104), ('movie_waste_time', 101), ('feel_good_movie', 97), ('mystery_science_theater', 97), ('george_c_scott', 93), ('highly_recommend_movie', 93), ('high_school_student', 92), ('blah_blah_blah', 92), ('texas_chainsaw_massacre', 91), ('film_take_place', 91), ('william_h_macy', 89), ('movie_take_place', 87), ('local_video_store', 87), ('kung_fu_movie', 86), ('film_worth_watching', 86), ('blair_witch_project', 85), ('5_year_old', 85), ('40_year_old', 85), ('15_year_old', 84), ('story_take_place', 82), ('long_time_ago', 82), ('second_world_war', 81), ('plan_9_outer', 80), ('9_outer_space', 80), ('bad_bad_bad', 79), ('nightmare_elm_street', 79), ('tour_de_force', 77), ('waste_time_watching', 76), ('saturday_night_live', 76), ('movie_seen_long', 76), ('science_theater_3000', 75), ('best_film_seen', 74), ('13_year_old', 73), ('8_year_old', 73), ('highly_recommend_film', 73), ('best_thing_movie', 73), ('martial_art_film', 72), ('movie_seen_life', 71), ('looking_forward_seeing', 71), ('actually_pretty_good', 71), ('hand_held_camera', 70), ('minute_running_time', 69), ('total_waste_time', 69), ('saving_private_ryan', 69), ('year_old_daughter', 69), ('film_seen_year', 67), ('good_thing_film', 67), ('pretty_good_movie', 67), ('movie_worth_seeing', 67), ('robert_de_niro', 67), ('martial_art_movie', 67), ('worst_movie_time', 66), ('night_living_dead', 66), ('samuel_l_jackson', 66), ('fast_forward_button', 65), ('breath_fresh_air', 65), ('film_worth_seeing', 64), ('17_year_old', 63), ('let_start_saying', 63), ('black_white_film', 62), ('movie_pretty_good', 62), ('die_hard_fan', 61), ('year_old_virgin', 61), ('movie_low_budget', 61), ('watching_paint_dry', 60), ('year_old_son', 60), ('movie_bad_movie', 60), ('11_year_old', 60), ('robert_downey_jr', 60), ('movie_read_book', 59), ('good_old_fashioned', 59), ('movie_10_10', 59), ('20_year_old', 59), ('movie_seen_year', 58), ('tommy_lee_jones', 58)]
# Wall time: 33.4 s

# %%
# %%time
all_words_dict = dict(all_words_freq)
wordCloud = WordCloud(max_words=WC_max_words, height=WC_height, width=WC_width,stopwords=stopwords, colormap=colormap)
wordCloud.generate_from_frequencies(all_words_dict)
plt.figure(figsize=(20,10), facecolor='k')
plt.imshow(wordCloud, interpolation='bilinear')
plt.axis("off")
plt.show()
wordCloud.to_file('wordcloud_all_trigram.jpg')
# Out:
# Wall time: 3.93 s
